# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/udemy_courses.csv')
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df[df['level'] == 'Intermediate Level']
# Out:
#       course_id                                       course_title  \
# 2       1006314  Financial Modeling for Business Analysts and C...
# 4       1011058       How To Maximize Your Profits Trading Options
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 27       447362  Create Your Own Hedge Fund: Trade Stocks Like ...
# 35       434774  Options Trading Stocks: Proven Toolbox For Fin...
# ...         ...                                                ...
# 3619     973932    Learn Spring Security 4 Intermediate - Hands On
# 3635     576054  WordPress Development - Themes, Plugins & Sing...
# 3639     261148           create a search engine for your website!
# 3644     554136  Building Responsive Websites with Bootstrap 3 ...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
#
#                                                     url  is_paid  price  \
# 2     https://www.udemy.com/financial-modeling-for-b...     True     45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df.cov()
# Out:
#                      course_id      is_paid         price  num_subscribers  \
# course_id         1.178365e+11 -1304.664775  2.980400e+06    -5.476311e+08
# is_paid          -1.304665e+03     0.077202  5.568491e+00    -7.028578e+02
# price             2.980400e+06     5.568491  3.721702e+03     2.943636e+04
# num_subscribers  -5.476311e+08  -702.857848  2.943636e+04     9.032824e+07
# num_reviews      -1.880135e+07   -22.735294  6.488394e+03     5.778436e+06
# num_lectures     -4.262617e+05     1.575935  1.014806e+03     7.553634e+04
# content_duration -1.189163e+05     0.158816  1.083766e+02     9.311616e+03
#
#                    num_reviews   num_lectures  content_duration
# course_id        -1.880135e+07 -426261.654968    -118916.250328
# is_paid          -2.273529e+01       1.575935          0.158816
# price             6.488394e+03    1014.805604        108.376552
# num_subscribers   5.778436e+06   75536.340427       9311.616119
# ...

# %%
df.drop_duplicates()
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.sort_values(by = 'num_reviews', ascending = False)
# Out:
#       course_id                                       course_title  \
# 3230     625204                         The Web Developer Bootcamp
# 3232     764164              The Complete Web Developer Course 2.0
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3254     705264                            Modern React with Redux
# ...         ...                                                ...
# 1021    1010988         Economics for beginners - Various Concepts
# 1022     855816                       Investing in Stocks & Shares
# 1472     181268               Photoshop: Creando elemental de aire
# 1024     813516     Learn Financial Modeling from Scratch - Part 3
# 1592    1127944  Designing With Halftones: Create a Dot Pattern...
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# ...

# %%
df[df['is_paid'] == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
sns.displot(df, x = "price")
plt.show()

# %%
sns.displot(df, x = "num_subscribers")
plt.show()

# %%
df['num_subscribers'].max()
# Out:
# 268923

# %%
sns.displot(df, x = "price", hue = "level", multiple = "stack")
plt.show()

# %%
sns.relplot(x = "num_lectures", y = "content_duration", data = df)
plt.show()

# %%
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df.groupby('subject')[['price','num_lectures','content_duration']].mean()
# Out:
#                          price  num_lectures  content_duration
# subject
# Business Finance     68.552301     32.430962          3.552999
# Graphic Design       57.827529     32.054726          3.580542
# Musical Instruments  49.558824     38.316176          2.854387
# Web Development      77.033333     52.817500          5.594792

# %%
df.query('price >= 200 and num_subscribers > 3000')
# Out:
#       course_id                                       course_title  \
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 26       353044  Investing 101: The Complete Online Investing C...
# 37       888716  Introduction to Finance, Accounting, Modeling ...
# 44       301442       Black Algo Trading: Build Your Trading Robot
# 47       260470  Forex Robots: Expect To Earn 175% P.A. Forex R...
# ...         ...                                                ...
# 3489     615106  Ultimate guide to Social Media Web development...
# 3561     513958  Complete JavaScript Course for Beginners with ...
# 3565     564366  Ajax in JavaScript and JQuery, with PHP - Crea...
# 3569     260756  The Essential Web Developer Course - Build 12 ...
# 3585     507992  Wordpress For Beginners: Create a Professional...
#
#                                                     url  is_paid  price  \
# 10    https://www.udemy.com/trading-with-amazons-aws...     True    200
# ...
